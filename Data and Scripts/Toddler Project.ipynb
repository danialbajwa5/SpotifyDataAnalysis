# %% [markdown]
# ### Loading the Datasets
# We will load in all our packages and our datasets all at once in the beginning.

# %%
# Loading all packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading both datasets
baby = pd.read_csv("spotify_history.csv")
toddler = pd.read_csv("spotify_additional_metadata.csv")

# %% [markdown]
# ### Merging the Datasets
# Now, we will merge our two datasets into one.

# %%
# Merge datasets using the common key "spotify_track_uri"
merged_data = pd.merge(baby, toddler, on="spotify_track_uri", how="inner")

# Save the new merged dataset
merged_data.to_csv("merged_spotify_data.csv", index=False)

# Display a sample of merged data
merged_data.head()
# Out:
#         spotify_track_uri                   ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 3  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 4  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
#
#                                       track_name    artist_name  \
# 0                            Say It, Just Say It   The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)  Calvin Harris
# 2  Drinking from the Bottle (feat. Tinie Tempah)  Calvin Harris
# 3                                    Born To Die   Lana Del Rey
# 4                                    Born To Die   Lana Del Rey
#
#                            album_name reason_start reason_end  shuffle  \
# 0                Waiting For The Dawn     autoplay   clickrow    False
# 1                           18 Months     clickrow   clickrow    False
# 2                           18 Months     clickrow   clickrow    False
# 3  Born To Die - The Paradise Edition     clickrow    unknown    False
# 4  Born To Die - The Paradise Edition     clickrow    unknown    False
#
#    skipped genre  popularity  release_year  user_rating
# 0    False   Pop          70          2015          1.3
# 1    False  Rock          90          1990          4.6
# 2    False  Rock          57          2009          3.9
# 3    False  Jazz          53          1998          3.0
# 4    False  Rock          65          2010          4.8

# %% [markdown]
# ### Merge Explanation
# I chose an _inner join_ because it ensures that only records present in both datasets are included in the final merged dataset. This:
# - Removes any unmatched records from either dataset, maintaining data accuracy.
# - Ensures that each spotify_track_uri in the final dataset has both playback data and additional metadata.
#
# Since an inner join only keeps the matching keys in the datasets, no NA values are created from missing matches.
# However, if the datasets had inconsistent data, an outer join could have been used to keep all the same records in the merged dataset and fill missing values with NA.

# %% [markdown]
# ### Taking a Look at our Merged Dataset
# Looking at the final product of our merged data.

# %%
from IPython.display import display # Table Created Using GPT (table that showcases the data)
display(merged_data)
# Out:
#               spotify_track_uri                   ts    platform  ms_played  \
# 0        2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1        1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2        1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 3        487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 4        487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# ...                         ...                  ...         ...        ...
# 6043051  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
# 6043052  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
# 6043053  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
# 6043054  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
# 6043055  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
#
#                                             track_name     artist_name  \
# 0                                  Say It, Just Say It    The Mowgli's
# 1        Drinking from the Bottle (feat. Tinie Tempah)   Calvin Harris
# 2        Drinking from the Bottle (feat. Tinie Tempah)   Calvin Harris
# 3                                          Born To Die    Lana Del Rey
# 4                                          Born To Die    Lana Del Rey
# ...                                                ...             ...
# 6043051                          God Only Knows - Mono  The Beach Boys
# 6043052                          God Only Knows - Mono  The Beach Boys
# 6043053                          God Only Knows - Mono  The Beach Boys
# 6043054                          God Only Knows - Mono  The Beach Boys
# 6043055                          God Only Knows - Mono  The Beach Boys
#
#                                  album_name reason_start reason_end  shuffle  \
# 0                      Waiting For The Dawn     autoplay   clickrow    False
# 1                                 18 Months     clickrow   clickrow    False
# 2                                 18 Months     clickrow   clickrow    False
# 3        Born To Die - The Paradise Edition     clickrow    unknown    False
# 4        Born To Die - The Paradise Edition     clickrow    unknown    False
# ...                                     ...          ...        ...      ...
# 6043051                          Pet Sounds       fwdbtn     fwdbtn     True
# 6043052                          Pet Sounds       fwdbtn     fwdbtn     True
# 6043053                          Pet Sounds       fwdbtn     fwdbtn     True
# 6043054                          Pet Sounds       fwdbtn     fwdbtn     True
# 6043055                          Pet Sounds       fwdbtn     fwdbtn     True
#
#          skipped genre  popularity  release_year  user_rating
# 0          False   Pop          70          2015          1.3
# 1          False  Rock          90          1990          4.6
# 2          False  Rock          57          2009          3.9
# 3          False  Jazz          53          1998          3.0
# 4          False  Rock          65          2010          4.8
# ...          ...   ...         ...           ...          ...
# 6043051     True   Pop          98          2007          1.4
# 6043052     True   Pop          60          2006          4.4
# 6043053     True  Jazz          88          2008          3.9
# 6043054     True  Rock          69          2021          2.4
# 6043055     True   Pop          54          2021          4.4
#
# [6043056 rows x 15 columns]
